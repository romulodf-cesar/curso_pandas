# %% [markdown]
# # Kaggle

# %% [markdown]
# - Algum dataset que trata do comportamento de jogadores x jogos

# %% [markdown]
# - Desafio:relatorio dos tipos de variaveis na estatistica descritiva

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Variavel = Target

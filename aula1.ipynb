# %%
print("alo mundo")
# Out:
# alo mundo

# %%
! pip install pandas
# Out:
# ...
#   Using cached pandas-2.3.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.3.4-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
# Using cached pandas-2.3.3-cp313-cp313-win_amd64.whl (11.0 MB)
# Using cached numpy-2.3.4-cp313-cp313-win_amd64.whl (12.8 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# ...
#
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("datasets/tempo_salarios.csv")

# %%
df.head()
# Out:
#    AnosdeExperiencia  Salario
# 0                1.1  39343.0
# 1                1.3  46205.0
# 2                1.5  37731.0
# 3                2.0  43525.0
# 4                2.2  39891.0

# %%
df.tail()
# Out:
#     AnosdeExperiencia   Salario
# 25                9.0  105582.0
# 26                9.5  116969.0
# 27                9.6  112635.0
# 28               10.3  122391.0
# 29               10.5  121872.0

# %%
# Correção
jogos_dict = {
    "oxo":1952,
    "computer_space":1971,
    "magnavox_odyssey":1972,
    "pong":1972,
    "pac man":1980
}

# %%
jogos_series = pd.Series(jogos_dict)

# %%
print(jogos_series)
# Out:
# oxo                 1952
# computer_space      1971
# magnavox_odyssey    1972
# pong                1972
# pac man             1980
# dtype: int64

# %%
jogos_series['pac man']
# Out:
# np.int64(1980)

# %% [markdown]
# "Quantos jogos existem no planeta terra?"
# R = 1000000
# POPULACAO

# %% [markdown]
# "Quantos pessoas existem no DF"
# 400000000
# POPULACAO

# %% [markdown]
# Series dos jogos historicos
# AMOSTRA
# AMOSTRA = ESTATISTICA

# %% [markdown]
# TODOS OS ALUNOS DO SENAC
# POPULACAO = parametros

# %%
import pandas as pd

# %% [markdown]
# # Estatística

# %% [markdown]
# - O que é estatística
# - Você lembra do IBGE...
# - Conhece muito a média...
# - População = parâmetros
# - Amostra = estatística
# - Qual o tamanho da minha amostra...

# %%
# quero fazer uma pesquisa de funcionários, seus salários e tempo de experiência
# questionários, entrevistas, primeiras análises
# percentuais
# minha origem = população = parâmetros
# minha origem = amostra = estatísticas

df_total = pd.read_csv('datasets/tempo_salarios.csv')

# %%
# qual o tamanho da minha amostra
print(len(df_total))
# Out:
# 30

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   AnosdeExperiencia  30 non-null     float64
#  1   Salario            30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # dontpad : tiasenac
# # Exercício
# - copie e cole a imagem das variáveis e seus tipos
# - considere nosso dataset e informe  para a turma quais os tipos de variáveis

# %% [markdown]
# # Quantitativos

# %% [markdown]
# - Discretos: resultam de um conjunto finito ou enumerável de valores possíveis (contagens)
# - Contínuos: resultam em um número infínito de valores possíveis (mensurações)

# %% [markdown]
# # Estatística Descritiva

# %% [markdown]
# - Medidas de Tendência Central

# %%
df_total.describe()
# Out:
#        AnosdeExperiencia        Salario
# count          30.000000      30.000000
# mean            5.313333   76003.000000
# std             2.837888   27414.429785
# min             1.100000   37731.000000
# 25%             3.200000   56720.750000
# 50%             4.700000   65237.000000
# 75%             7.700000  100544.750000
# max            10.500000  122391.000000

# %%
# Exercício: fazer um comparativo entre os dois datasets
df_faltando = pd.read_csv('datasets/tempo_salarios_incompleto.csv')

# %%
df_faltando.describe()
# Out:
#        AnosdeExperiencia        Salario
# count          30.000000      25.000000
# mean            5.313333   78527.280000
# std             2.837888   28981.061348
# min             1.100000   37731.000000
# 25%             3.200000   56642.000000
# 50%             4.700000   66029.000000
# 75%             7.700000  105582.000000
# max            10.500000  122391.000000

# %%
df_total.Salario.mean()
# Out:
# np.float64(76003.0)

# %% [markdown]
# # Exercícios sobre tendência central

# %% [markdown]
# - Exemplo 01: Um pesquisador interessado em avaliar o nível de ruido em um determinado cruzamento movimentado da cidade, mediu o nível de ruído (em decibéis) durante 18 dias.
